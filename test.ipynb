# %% [markdown]
# <a href="https://colab.research.google.com/github/hannapsk/CB2330-scientific_computing_in_life_sciences/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys, platform, subprocess
print("python ", sys.version.split()[0])
print("machine ", platform.platform())
print(subprocess.run(["free", "-h"], capture_output=True, text=True).stdout)
# Out:
# python  3.13.15
# machine  Linux-6.6.122+-x86_64-with-glibc2.35
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       1.0Gi       8.4Gi       5.0Mi       3.2Gi        11Gi
# Swap:             0B          0B          0B

# %%
import numpy as np
my_array = np.array([4, 23, 5, 67, 87, 34, 85])
print((np.sum(my_array)))
# Out:
# 305
